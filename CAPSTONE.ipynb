# %%
import pandas as pd

# %%
country_wise = pd.read_csv("C:\\Users\\USER\\Desktop\\3mtt assignment\\captone project\\country_wise_latest.csv")

# %%
covid_19_clean_complete = pd.read_csv("C:\\Users\\USER\\Desktop\\3mtt assignment\\captone project\\covid_19_clean_complete.csv")

# %%
day_wise = pd.read_csv("C:\\Users\\USER\\Desktop\\3mtt assignment\\captone project\\day_wise.csv")
full_grouped = pd.read_csv("C:\\Users\\USER\Desktop\\3mtt assignment\\captone project\\full_grouped.csv")
usa_country = pd.read_csv("C:\\Users\\USER\\Desktop\\3mtt assignment\\captone project\\usa_county_wise.csv")
worldometer = pd.read_csv("C:\\Users\\USER\\Desktop\\3mtt assignment\\captone project\\worldometer_data.csv")

# %%
covid_19_clean_complete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  49068 non-null  object
#  2   Lat             49068 non-null  float64
#  3   Long            49068 non-null  float64
#  4   Date            49068 non-null  object
#  5   Confirmed       49068 non-null  int64
#  6   Deaths          49068 non-null  int64
#  7   Recovered       49068 non-null  int64
#  8   Active          49068 non-null  int64
#  9   WHO Region      49068 non-null  object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 3.7+ MB

# %%
covid_19_clean_complete.isnull().sum()
# Out:
# Province/State    34404
# Country/Region        0
# Lat                   0
# Long                  0
# Date                  0
# Confirmed             0
# Deaths                0
# Recovered             0
# Active                0
# WHO Region            0
# dtype: int64

# %%
country_wise.isnull().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %%
day_wise.isnull().sum()
# Out:
# Date                      0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# No. of countries          0
# dtype: int64

# %%
full_grouped.isnull().sum()
# Out:
# Date              0
# Country/Region    0
# Confirmed         0
# Deaths            0
# Recovered         0
# Active            0
# New cases         0
# New deaths        0
# New recovered     0
# WHO Region        0
# dtype: int64

# %%
worldometer.isnull().sum()
# Out:
# Country/Region        0
# Continent             1
# Population            1
# TotalCases            0
# NewCases            205
# TotalDeaths          21
# NewDeaths           206
# TotalRecovered        4
# NewRecovered        206
# ActiveCases           4
# Serious,Critical     87
# Tot Cases/1M pop      1
# Deaths/1M pop        22
# TotalTests           18
# Tests/1M pop         18
# WHO Region           25
# dtype: int64

# %%
worldometer.fillna(" ")
# Out:
#             Country/Region      Continent    Population  TotalCases NewCases  \
# 0                      USA  North America   331198130.0     5032179
# 1                   Brazil  South America   212710692.0     2917562
# 2                    India           Asia  1381344997.0     2025409
# 3                   Russia         Europe   145940924.0      871894
# 4             South Africa         Africa    59381566.0      538184
# ..                     ...            ...           ...         ...      ...
# 204             Montserrat  North America        4992.0          13
# 205  Caribbean Netherlands  North America       26247.0          13
# 206       Falkland Islands  South America        3489.0          13
# 207           Vatican City         Europe         801.0          12
# 208         Western Sahara         Africa      598682.0          10
#
#     TotalDeaths NewDeaths TotalRecovered NewRecovered ActiveCases  \
# ...

# %%
worldometer.isnull().sum()
# Out:
# Country/Region        0
# Continent             1
# Population            1
# TotalCases            0
# NewCases            205
# TotalDeaths          21
# NewDeaths           206
# TotalRecovered        4
# NewRecovered        206
# ActiveCases           4
# Serious,Critical     87
# Tot Cases/1M pop      1
# Deaths/1M pop        22
# TotalTests           18
# Tests/1M pop         18
# WHO Region           25
# dtype: int64

# %%
worldometer.fillna(" ")
# Out:
#             Country/Region      Continent    Population  TotalCases NewCases  \
# 0                      USA  North America   331198130.0     5032179
# 1                   Brazil  South America   212710692.0     2917562
# 2                    India           Asia  1381344997.0     2025409
# 3                   Russia         Europe   145940924.0      871894
# 4             South Africa         Africa    59381566.0      538184
# ..                     ...            ...           ...         ...      ...
# 204             Montserrat  North America        4992.0          13
# 205  Caribbean Netherlands  North America       26247.0          13
# 206       Falkland Islands  South America        3489.0          13
# 207           Vatican City         Europe         801.0          12
# 208         Western Sahara         Africa      598682.0          10
#
#     TotalDeaths NewDeaths TotalRecovered NewRecovered ActiveCases  \
# ...

# %%
worldometer.isnull().sum()
# Out:
# Country/Region        0
# Continent             1
# Population            1
# TotalCases            0
# NewCases            205
# TotalDeaths          21
# NewDeaths           206
# TotalRecovered        4
# NewRecovered        206
# ActiveCases           4
# Serious,Critical     87
# Tot Cases/1M pop      1
# Deaths/1M pop        22
# TotalTests           18
# Tests/1M pop         18
# WHO Region           25
# dtype: int64

# %%
worldometer['NewCases']= worldometer['NewCases'].fillna(' ')

# %%
worldometer.isnull().sum()
# Out:
# Country/Region        0
# Continent             1
# Population            1
# TotalCases            0
# NewCases              0
# TotalDeaths          21
# NewDeaths           206
# TotalRecovered        4
# NewRecovered        206
# ActiveCases           4
# Serious,Critical     87
# Tot Cases/1M pop      1
# Deaths/1M pop        22
# TotalTests           18
# Tests/1M pop         18
# WHO Region           25
# dtype: int64

# %%
worldometer['Continent'] = worldometer['Continent'].dropna()
worldometer['Population'] = worldometer['Population'].dropna()
worldometer.isnull().sum()
# Out:
# Country/Region        0
# Continent             1
# Population            1
# TotalCases            0
# NewCases              0
# TotalDeaths          21
# NewDeaths           206
# TotalRecovered        4
# NewRecovered        206
# ActiveCases           4
# Serious,Critical     87
# Tot Cases/1M pop      1
# Deaths/1M pop        22
# TotalTests           18
# Tests/1M pop         18
# WHO Region           25
# dtype: int64

# %%
worldometer
# Out:
#             Country/Region      Continent    Population  TotalCases NewCases  \
# 0                      USA  North America  3.311981e+08     5032179
# 1                   Brazil  South America  2.127107e+08     2917562
# 2                    India           Asia  1.381345e+09     2025409
# 3                   Russia         Europe  1.459409e+08      871894
# 4             South Africa         Africa  5.938157e+07      538184
# ..                     ...            ...           ...         ...      ...
# 204             Montserrat  North America  4.992000e+03          13
# 205  Caribbean Netherlands  North America  2.624700e+04          13
# 206       Falkland Islands  South America  3.489000e+03          13
# 207           Vatican City         Europe  8.010000e+02          12
# 208         Western Sahara         Africa  5.986820e+05          10
#
#      TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# ...

# %%
country_wise.isnull().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %%
pd.set_option('display.max_colwidth', 50)

# %%
country_wise.isnull()
# Out:
#      Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0             False      False   False      False   False      False
# 1             False      False   False      False   False      False
# 2             False      False   False      False   False      False
# 3             False      False   False      False   False      False
# 4             False      False   False      False   False      False
# ..              ...        ...     ...        ...     ...        ...
# 182           False      False   False      False   False      False
# 183           False      False   False      False   False      False
# 184           False      False   False      False   False      False
# 185           False      False   False      False   False      False
# 186           False      False   False      False   False      False
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
worldometer.isnull().sum()
# Out:
# Country/Region        0
# Continent             1
# Population            1
# TotalCases            0
# NewCases              0
# TotalDeaths          21
# NewDeaths           206
# TotalRecovered        4
# NewRecovered        206
# ActiveCases           4
# Serious,Critical     87
# Tot Cases/1M pop      1
# Deaths/1M pop        22
# TotalTests           18
# Tests/1M pop         18
# WHO Region           25
# dtype: int64

# %%
worldometer.dropna()
# Out:
#    Country/Region      Continent   Population  TotalCases NewCases  \
# 5          Mexico  North America  129066160.0    462690.0   6590.0
# 28        Bolivia  South America   11688459.0     86423.0   1282.0
# 72       S. Korea           Asia   51273732.0     14519.0     20.0
#
#     TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 5       50517.0      819.0        308848.0        4140.0     103325.0
# 28       3465.0       80.0         27373.0         936.0      55585.0
# 72        303.0        1.0         13543.0          42.0        673.0
#
#     Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 5             3987.0            3585.0          391.0   1056915.0
# 28              71.0            7394.0          296.0    183583.0
# 72              18.0             283.0            6.0   1613652.0
#
#     Tests/1M pop      WHO Region
# 5         8189.0        Americas
# 28       15706.0        Americas
# 72       31471.0  WesternPacific

# %%
worldometer.isnull().sum()
# Out:
# Country/Region        0
# Continent             1
# Population            1
# TotalCases            0
# NewCases              0
# TotalDeaths          21
# NewDeaths           206
# TotalRecovered        4
# NewRecovered        206
# ActiveCases           4
# Serious,Critical     87
# Tot Cases/1M pop      1
# Deaths/1M pop        22
# TotalTests           18
# Tests/1M pop         18
# WHO Region           25
# dtype: int64

# %%
worldometer['TotalCases'] = worldometer['TotalCases'].astype(float)

# %%
worldometer['TotalRecovered'] = worldometer['TotalRecovered'].astype(float)

# %%
worldometer['TotalCases'] = worldometer['TotalCases'].fillna(0)
worldometer['TotalRecovered'] = worldometer['TotalRecovered'].fillna(0)
worldometer['NewDeaths'] = worldometer['NewDeaths'].fillna(0)

# %%
worldometer.isnull().sum()
# Out:
# Country/Region        0
# Continent             1
# Population            1
# TotalCases            0
# NewCases              0
# TotalDeaths          21
# NewDeaths             0
# TotalRecovered        0
# NewRecovered        206
# ActiveCases           4
# Serious,Critical     87
# Tot Cases/1M pop      1
# Deaths/1M pop        22
# TotalTests           18
# Tests/1M pop         18
# WHO Region           25
# dtype: int64

# %%
plt.scatter (worldometer['Country/Region'], worldometer['ratio'])
plt.xlabel()
plt.ylabel()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ratio'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[113], line 1
# ...

# %%
worldometer['WHO Region'].hist()
# Out:
# <Axes: >

# %%
worldometer['WHO Region'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Distribution of WHO Regions')
plt.show()

# %%
import matplotlib
from matplotlib import pyplot as plt

# %%
plt.plot(worldometer['ActiveCases'], worldometer[)
