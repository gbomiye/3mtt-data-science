# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np

# %%
Employees = pd.read_csv('C:\\Users\\andre\\Desktop\\3MTT\\New\\employees.csv')

# %%
Employees
# Out:
#                      Name  Age    Salary
# 0            Marie Phelps   26  $7357.73
# 1            Bertie Lynch   63  $6776.85
# 2               Eva Black   34  $5717.81
# 3         Winnie Fletcher   39  $9693.86
# 4            Dora Manning   23  $3164.16
# 5           Leroy Francis   34  $2907.33
# 6            Lilly Sparks   26   $763.32
# 7         William Freeman   46  $3148.31
# 8          Effie Morrison   59  $1664.93
# 9             Nancy Riley   41  $2472.41
# 10            Joshua Lane   20  $1054.93
# 11           Darrell Beck   55  $9226.00
# 12          Viola Patrick   41  $8744.87
# 13          Ella Reynolds   27  $4948.28
# 14          Tyler Wilkins   35  $5758.26
# 15             Gavin Ford   40  $5908.92
# 16             Ida Harper   53  $4127.28
# 17      Marguerite Horton   35   $130.55
# 18          Hunter Gibson   27  $6926.67
# 19             Wayne Ford   27   $705.08
# 20        Franklin Cannon   65  $4349.35
# 21           Joshua Lloyd   48  $7443.82
# ...

# %%
Employees.head()
# Out:
#               Name  Age    Salary
# 0     Marie Phelps   26  $7357.73
# 1     Bertie Lynch   63  $6776.85
# 2        Eva Black   34  $5717.81
# 3  Winnie Fletcher   39  $9693.86
# 4     Dora Manning   23  $3164.16

# %%
Employees.tail()
# Out:
#                 Name  Age    Salary
# 95     Sadie Ballard   22  $9543.37
# 96   Nicholas Farmer   57  $1655.97
# 97  Carrie Patterson   64   $108.09
# 98   Barbara Bridges   46  $4404.81
# 99  Lottie McCormick   19  $4885.87

# %%
Employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    100 non-null    object
#  1   Age     100 non-null    int64
#  2   Salary  100 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 2.5+ KB

# %%
Employees.describe()
# Out:
#               Age
# count  100.000000
# mean    41.740000
# std     14.445733
# min     18.000000
# 25%     29.750000
# 50%     40.500000
# 75%     54.000000
# max     65.000000

# %%
Employees.isnull().sum()
# Out:
# Name      0
# Age       0
# Salary    0
# dtype: int64

# %%
Employees['Salary'].max()
# Out:
# '$9894.38'

# %%
Employees['Salary'].min()
# Out:
# '$1054.93'

# %%
Employees['Age'].max()
# Out:
# 65

# %%
Employees['Age'].min()
# Out:
# 18

# %%
Employees_above30 = Employees[Employees['Age']>=30]

# %%
Employees_above30
# Out:
#                      Name  Age    Salary
# 1            Bertie Lynch   63  $6776.85
# 2               Eva Black   34  $5717.81
# 3         Winnie Fletcher   39  $9693.86
# 5           Leroy Francis   34  $2907.33
# 7         William Freeman   46  $3148.31
# 8          Effie Morrison   59  $1664.93
# 9             Nancy Riley   41  $2472.41
# 11           Darrell Beck   55  $9226.00
# 12          Viola Patrick   41  $8744.87
# 14          Tyler Wilkins   35  $5758.26
# 15             Gavin Ford   40  $5908.92
# 16             Ida Harper   53  $4127.28
# 17      Marguerite Horton   35   $130.55
# 20        Franklin Cannon   65  $4349.35
# 21           Joshua Lloyd   48  $7443.82
# 22          Myrtle Bowers   39  $4704.06
# 23         Willie Pittman   56  $7931.22
# 24             Lou Carter   51  $4745.48
# 25         Ronald Wheeler   63  $4035.58
# 26       Frederick Keller   30  $9314.40
# 28            Seth Harmon   61   $228.97
# 29         Wayne Guerrero   63  $3273.52
# ...

# %%
Employees_below30 = Employees[Employees['Age']<30]

# %%
Employees_below30
# Out:
#                 Name  Age    Salary
# 0       Marie Phelps   26  $7357.73
# 4       Dora Manning   23  $3164.16
# 6       Lilly Sparks   26   $763.32
# 10       Joshua Lane   20  $1054.93
# 13     Ella Reynolds   27  $4948.28
# 18     Hunter Gibson   27  $6926.67
# 19        Wayne Ford   27   $705.08
# 27    Johanna Mendez   22   $401.27
# 33   Rosalie Douglas   24  $4906.72
# 35       Nora Medina   23  $8754.44
# 42      Johnny Mason   19  $9548.75
# 51      Lottie Klein   24  $2894.88
# 52      Lenora Burns   19  $5042.01
# 53     Wesley Abbott   18   $606.99
# 58      Scott Watson   27  $8442.91
# 70    Michael Barton   20  $9665.22
# 71        Tony Bryan   19  $2543.71
# 74        Thomas Fox   21  $6540.37
# 78   Anthony Gregory   19  $3484.80
# 82       Lelia McCoy   22  $1598.47
# 84      Nathan Hicks   29  $4793.41
# 91   Calvin Mitchell   29  $2349.33
# 93   Caroline Ortega   22  $7475.52
# 95     Sadie Ballard   22  $9543.37
# 99  Lottie McCormick   19  $4885.87

# %%
Employees_below30.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    25 non-null     object
#  1   Age     25 non-null     int64
#  2   Salary  25 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 800.0+ bytes

# %%
Employees_above30['Salary']
# Out:
# 1     $6776.85
# 2     $5717.81
# 3     $9693.86
# 5     $2907.33
# 7     $3148.31
# 8     $1664.93
# 9     $2472.41
# 11    $9226.00
# 12    $8744.87
# 14    $5758.26
# 15    $5908.92
# 16    $4127.28
# 17     $130.55
# 20    $4349.35
# 21    $7443.82
# 22    $4704.06
# 23    $7931.22
# 24    $4745.48
# 25    $4035.58
# 26    $9314.40
# 28     $228.97
# 29    $3273.52
# 30    $4513.31
# 31    $6888.21
# 32    $2210.62
# 34    $6813.44
# 36    $4925.91
# 37    $5163.44
# 38    $2672.02
# 39    $5450.98
# 40    $9894.38
# 41    $2476.10
# 43    $4010.10
# 44     $712.28
# 45    $6061.01
# 46    $6710.65
# 47    $6217.65
# 48    $3056.79
# 49    $1338.29
# 50    $2446.51
# 54     $724.19
# 55     $678.20
# 56     $856.37
# 57    $4815.26
# 59    $2667.94
# 60    $9227.46
# 61    $6606.85
# 62    $7554.82
# 63    $2387.42
# 64     $244.07
# 65    $8015.51
# 66    $5732.24
# 67    $2671.64
# 68     $281.28
# 69    $3167.48
# 72    $8474.73
# 73    $8880.76
# 75    $5176.05
# ...

# %%
Employees_above30['Salary'] =Employees_above30['Salary'].str.strip('$')
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_11564\413562436.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Employees_above30['Salary'] =Employees_above30['Salary'].str.strip('$')

# %%
Employees_above30['Salary']
# Out:
# 1     6776.85
# 2     5717.81
# 3     9693.86
# 5     2907.33
# 7     3148.31
# 8     1664.93
# 9     2472.41
# 11    9226.00
# 12    8744.87
# 14    5758.26
# 15    5908.92
# 16    4127.28
# 17     130.55
# 20    4349.35
# 21    7443.82
# 22    4704.06
# 23    7931.22
# 24    4745.48
# 25    4035.58
# 26    9314.40
# 28     228.97
# 29    3273.52
# 30    4513.31
# 31    6888.21
# 32    2210.62
# 34    6813.44
# 36    4925.91
# 37    5163.44
# 38    2672.02
# 39    5450.98
# 40    9894.38
# 41    2476.10
# 43    4010.10
# 44     712.28
# 45    6061.01
# 46    6710.65
# 47    6217.65
# 48    3056.79
# 49    1338.29
# 50    2446.51
# 54     724.19
# 55     678.20
# 56     856.37
# 57    4815.26
# 59    2667.94
# 60    9227.46
# 61    6606.85
# 62    7554.82
# 63    2387.42
# 64     244.07
# 65    8015.51
# 66    5732.24
# 67    2671.64
# 68     281.28
# 69    3167.48
# 72    8474.73
# 73    8880.76
# 75    5176.05
# 76    4649.74
# 77    5297.09
# 79    4314.11
# 80    5512.78
# ...

# %%
Employees_above30['Salary'] = Employees_above30['Salary'].astype(float)
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_11564\1168084343.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Employees_above30['Salary'] = Employees_above30['Salary'].astype(float)

# %%
Employees_above30['Salary'].describe()
# Out:
# count      75.000000
# mean     4610.359467
# std      2771.898349
# min       108.090000
# 25%      2572.020000
# 50%      4649.740000
# 75%      6515.995000
# max      9894.380000
# Name: Salary, dtype: float64

# %%
Employees_above30['Salary'].mean()
# Out:
# 4610.359466666666

# %%
Employees_above30
# Out:
#                      Name  Age   Salary
# 1            Bertie Lynch   63  6776.85
# 2               Eva Black   34  5717.81
# 3         Winnie Fletcher   39  9693.86
# 5           Leroy Francis   34  2907.33
# 7         William Freeman   46  3148.31
# 8          Effie Morrison   59  1664.93
# 9             Nancy Riley   41  2472.41
# 11           Darrell Beck   55  9226.00
# 12          Viola Patrick   41  8744.87
# 14          Tyler Wilkins   35  5758.26
# 15             Gavin Ford   40  5908.92
# 16             Ida Harper   53  4127.28
# 17      Marguerite Horton   35   130.55
# 20        Franklin Cannon   65  4349.35
# 21           Joshua Lloyd   48  7443.82
# 22          Myrtle Bowers   39  4704.06
# 23         Willie Pittman   56  7931.22
# 24             Lou Carter   51  4745.48
# 25         Ronald Wheeler   63  4035.58
# 26       Frederick Keller   30  9314.40
# 28            Seth Harmon   61   228.97
# 29         Wayne Guerrero   63  3273.52
# ...

# %%
import seaborn as sns

# %%
sns.barplot(x= 'Age', y= 'Salary', data = Employees_above30)
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %%
sns.lineplot(x= 'Age', y= 'Salary', data= Employees_above30)
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %%
Sales = pd.read_csv('C:\\Users\\andre\\Desktop\\3MTT\\New\\sales.csv')

# %%
Sales
# Out:
#           Date  Product  Quantity Region ID
# 0   08/01/1907  t-shirt        13        CO
# 1   07/30/1920      hat        15        AK
# 2   04/22/1998    skirt         3        PA
# 3   11/18/1937  t-shirt        14        NM
# 4   10/09/1948    skirt        12        KS
# 5   06/27/1904      tie         3        MI
# 6   12/27/2020    shirt         1        WI
# 7   09/22/2001      hat        18        MD
# 8   08/13/2054    shoes        16        NV
# 9   01/20/2033   shorts        14        NH
# 10  03/02/1941   wallet        13        NJ
# 11  01/19/2061    shirt        10        NJ
# 12  09/14/1995    skirt        18        NJ
# 13  04/10/1928  t-shirt        15        KS
# 14  12/28/1936      hat         7        MO
# 15  11/13/1915    pants        10        VT
# 16  06/06/2058    skirt         6        ND
# 17  07/05/1960   shorts         6        IL
# 18  07/10/1961   shorts         6        ND
# 19  04/20/2045   shorts        11        HI
# ...

# %%
Sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       100 non-null    object
#  1   Product    100 non-null    object
#  2   Quantity   100 non-null    int64
#  3   Region ID  100 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 3.3+ KB

# %%
Sales.describe()
# Out:
#         Quantity
# count  100.00000
# mean    10.85000
# std      5.92951
# min      0.00000
# 25%      6.00000
# 50%     11.50000
# 75%     15.25000
# max     20.00000

# %%
Regions = pd.read_csv('C:\\Users\\andre\\Desktop\\3MTT\\New\\regions.csv')

# %%
Regions
# Out:
#              Region Name Region ID
# 0                Alabama        AL
# 1                 Alaska        AK
# 2                Arizona        AZ
# 3               Arkansas        AR
# 4             California        CA
# 5               Colorado        CO
# 6            Connecticut        CT
# 7               Delaware        DE
# 8   District of Columbia        DC
# 9                Florida        FL
# 10               Georgia        GA
# 11                Hawaii        HI
# 12                 Idaho        ID
# 13              Illinois        IL
# 14               Indiana        IN
# 15                  Iowa        IA
# 16                Kansas        KS
# 17              Kentucky        KY
# 18             Louisiana        LA
# 19                 Maine        ME
# 20               Montana        MT
# 21              Nebraska        NE
# 22                Nevada        NV
# 23         New Hampshire        NH
# 24            New Jersey        NJ
# 25            New Mexico        NM
# ...

# %%
Regions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Region Name  51 non-null     object
#  1   Region ID    51 non-null     object
# dtypes: object(2)
# memory usage: 948.0+ bytes

# %%
Regions.describe()
# Out:
#        Region Name Region ID
# count           51        51
# unique          51        51
# top        Alabama        AL
# freq             1         1

# %%
Sales_Reg = pd.merge(Sales, Regions, on= 'Region ID')

# %%
Sales_Reg
# Out:
#           Date  Product  Quantity Region ID           Region Name
# 0   08/01/1907  t-shirt        13        CO              Colorado
# 1   04/19/1911    pants         5        CO              Colorado
# 2   10/27/1981    socks        13        CO              Colorado
# 3   01/25/1926    skirt         5        CO              Colorado
# 4   07/30/1920      hat        15        AK                Alaska
# 5   11/11/2061   wallet         6        AK                Alaska
# 6   04/22/1998    skirt         3        PA          Pennsylvania
# 7   04/01/1907   wallet         8        PA          Pennsylvania
# 8   09/29/2044      tie         1        PA          Pennsylvania
# 9   01/25/2047   shorts         2        PA          Pennsylvania
# 10  11/18/1937  t-shirt        14        NM            New Mexico
# 11  10/09/1948    skirt        12        KS                Kansas
# 12  04/10/1928  t-shirt        15        KS                Kansas
# ...

# %%
pd.set_option('display.max_rows', None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pd.set_option('display.max_rows', None)
#
# NameError: name 'pd' is not defined

# %%
Sales_Reg
# Out:
#           Date  Product  Quantity Region ID           Region Name
# 0   08/01/1907  t-shirt        13        CO              Colorado
# 1   04/19/1911    pants         5        CO              Colorado
# 2   10/27/1981    socks        13        CO              Colorado
# 3   01/25/1926    skirt         5        CO              Colorado
# 4   07/30/1920      hat        15        AK                Alaska
# 5   11/11/2061   wallet         6        AK                Alaska
# 6   04/22/1998    skirt         3        PA          Pennsylvania
# 7   04/01/1907   wallet         8        PA          Pennsylvania
# 8   09/29/2044      tie         1        PA          Pennsylvania
# 9   01/25/2047   shorts         2        PA          Pennsylvania
# 10  11/18/1937  t-shirt        14        NM            New Mexico
# 11  10/09/1948    skirt        12        KS                Kansas
# 12  04/10/1928  t-shirt        15        KS                Kansas
# ...

# %%
Sales_Reg['Date'] = pd.to_datetime(Sales_Reg['Date'], format= '%m/%d/%Y')
Sales_Reg
# Out:
#          Date  Product  Quantity Region ID           Region Name
# 0  1907-08-01  t-shirt        13        CO              Colorado
# 1  1911-04-19    pants         5        CO              Colorado
# 2  1981-10-27    socks        13        CO              Colorado
# 3  1926-01-25    skirt         5        CO              Colorado
# 4  1920-07-30      hat        15        AK                Alaska
# 5  2061-11-11   wallet         6        AK                Alaska
# 6  1998-04-22    skirt         3        PA          Pennsylvania
# 7  1907-04-01   wallet         8        PA          Pennsylvania
# 8  2044-09-29      tie         1        PA          Pennsylvania
# 9  2047-01-25   shorts         2        PA          Pennsylvania
# 10 1937-11-18  t-shirt        14        NM            New Mexico
# 11 1948-10-09    skirt        12        KS                Kansas
# 12 1928-04-10  t-shirt        15        KS                Kansas
# ...

# %%
Sales_Reg.sort_values(by='Date', ascending=True, inplace= True)

# %%
Sales_Reg
# Out:
#          Date  Product  Quantity Region ID           Region Name
# 37 1900-09-25     belt        19        VT               Vermont
# 69 1901-04-09    pants         8        IN               Indiana
# 79 1901-06-14      tie        13        DE              Delaware
# 13 1904-06-27      tie         3        MI              Michigan
# 7  1907-04-01   wallet         8        PA          Pennsylvania
# 0  1907-08-01  t-shirt        13        CO              Colorado
# 66 1908-05-08      hat        14        WV         West Virginia
# 1  1911-04-19    pants         5        CO              Colorado
# 58 1912-02-28    shirt         3        SD          South Dakota
# 67 1913-01-01   shorts         4        DC  District of Columbia
# 47 1913-07-12      hat         5        WY               Wyoming
# 71 1915-07-28      hat         4        NY              New York
# 36 1915-11-13    pants        10        VT               Vermont
# ...

# %%
Sales_Reg.reset_index(drop=True)
# Out:
#          Date  Product  Quantity Region ID           Region Name
# 0  1900-09-25     belt        19        VT               Vermont
# 1  1901-04-09    pants         8        IN               Indiana
# 2  1901-06-14      tie        13        DE              Delaware
# 3  1904-06-27      tie         3        MI              Michigan
# 4  1907-04-01   wallet         8        PA          Pennsylvania
# 5  1907-08-01  t-shirt        13        CO              Colorado
# 6  1908-05-08      hat        14        WV         West Virginia
# 7  1911-04-19    pants         5        CO              Colorado
# 8  1912-02-28    shirt         3        SD          South Dakota
# 9  1913-01-01   shorts         4        DC  District of Columbia
# 10 1913-07-12      hat         5        WY               Wyoming
# 11 1915-07-28      hat         4        NY              New York
# 12 1915-11-13    pants        10        VT               Vermont
# ...

# %%
Salesbyregion = Sales_Reg.groupby('Region Name')['Quantity'].sum()

# %%
Salesbyregion
# Out:
# Region Name
# Alabama                 79
# Alaska                  21
# Arizona                 56
# California              64
# Colorado                36
# Connecticut             14
# Delaware                26
# District of Columbia     4
# Florida                 44
# Georgia                  7
# Hawaii                  11
# Idaho                    6
# Illinois                13
# Indiana                 17
# Iowa                    15
# Kansas                  27
# Louisiana               15
# Maryland                44
# Michigan                34
# Missouri                17
# Montana                 20
# Nevada                  46
# New Hampshire           53
# New Jersey              61
# New Mexico              14
# New York                20
# North Carolina          47
# North Dakota            21
# Oklahoma                13
# Oregon                   6
# Pennsylvania            14
# Rhode Island            20
# South Dakota            13
# Tennessee               24
# ...

# %%
Salesbyregion.sort_values(ascending=True)
# Out:
# Region Name
# District of Columbia     4
# Idaho                    6
# Oregon                   6
# Georgia                  7
# Wisconsin                9
# Hawaii                  11
# Virginia                11
# South Dakota            13
# Illinois                13
# Oklahoma                13
# Pennsylvania            14
# New Mexico              14
# Connecticut             14
# Iowa                    15
# Louisiana               15
# Wyoming                 15
# Missouri                17
# Indiana                 17
# Washington              18
# Rhode Island            20
# New York                20
# Montana                 20
# North Dakota            21
# Alaska                  21
# Texas                   21
# Tennessee               24
# Delaware                26
# Utah                    26
# Kansas                  27
# West Virginia           31
# Vermont                 32
# Michigan                34
# Colorado                36
# Maryland                44
# ...

# %%
plt.hist('Salesbyregion')
plt.xlabel= 'Quantity'
plt.ylabel= 'Region Name'

# %%
sns.histplot(Salesbyregion)
# Out:
# <Axes: xlabel='Quantity', ylabel='Count'>

# %%
sns.barplot(Salesbyregion)
# Out:
# <Axes: >

# %%
plt.pie(Salesbyregion)
# Out:
# ([<matplotlib.patches.Wedge at 0x25379522690>,
# ...
#  [Text(1.0713474900983175, 0.24942845759863821, ''),
#   Text(0.955534115164343, 0.5449353675043459, ''),
#   Text(0.8113934762068378, 0.7427251354094487, ''),
#   Text(0.5100019479649299, 0.974627114886497, ''),
#   Text(0.2104977974334292, 1.0796715599086952, ''),
#   Text(0.052532927111374444, 1.09874487100924, ''),
#   Text(-0.07479032863440235, 1.0974545123797879, ''),
#   Text(-0.16971813571199323, 1.0868283003356352, ''),
#   Text(-0.31864634736030667, 1.0528364095689011, ''),
#   Text(-0.47008564334588426, 0.9944945891859273, ''),
#   Text(-0.5212555214730333, 0.9686550889423315, ''),
#   Text(-0.5682851360342192, 0.9418343825548997, ''),
#   Text(-0.6192133868761909, 0.9091615816307446, ''),
#   Text(-0.6957531626150109, 0.8520138125119865, ''),
#   Text(-0.7715994380888784, 0.78398616514638, ''),
#   Text(-0.8610066349530753, 0.6845929992095902, ''),
#   Text(-0.9376960890416743, 0.5750878581538202, ''),
# ...

# %%
np.histogram(Salesbyregion)
# Out:
# (array([ 7, 12,  9,  3,  2,  4,  2,  1,  1,  1], dtype=int64),
#  array([ 4. , 11.5, 19. , 26.5, 34. , 41.5, 49. , 56.5, 64. , 71.5, 79. ]))
