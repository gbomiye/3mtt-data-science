# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
Cricket = pd.read_csv('C:\\Users\\Dell\\Desktop\\3MTT Practical\\Cricket.csv')

# %%
Cricket
# Out:
#                   Player       Span  Mat  Inns  NO   Runs    HS    Ave     BF  \
# 0       DG Bradman (AUS)  1928-1948   52    80  10   6996   334  99.94  9800+
# 1      YBK Jaiswal (IND)  2023-2024   11    20   1   1217  214*  64.05   1698
# 2         AC Voges (AUS)  2015-2016   20    31   7   1485  269*  61.87   2667
# 3        RG Pollock (SA)  1963-1970   23    41   4   2256   274  60.97  1707+
# 4        GA Headley (WI)  1930-1954   22    40   4   2190  270*  60.83   416+
# ..                   ...        ...  ...   ...  ..    ...   ...    ...    ...
# 67       B Mitchell (SA)  1929-1949   42    80   9   3471  189*  48.88   158+
# 68  Hon.FS Jackson (ENG)  1893-1905   20    33   4   1415  144*  48.79    NaN
# 69   TT Samaraweera (SL)  2001-2013   81   132  20   5462   231  48.76  11641
# 70       RN Harvey (AUS)  1948-1963   79   137  10   6149   205  48.41  1799+
# 71      RT Ponting (AUS)  1995-2012  168   287  29  13378   257  51.85  22782
#
#        SR  100  50   0    4s  6s
# ...

# %%
Cricket.head()
# Out:
#               Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0   DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1  YBK Jaiswal (IND)  2023-2024   11    20   1  1217  214*  64.05   1698
# 2     AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3    RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4    GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
#
#       SR  100  50  0   4s  6s
# 0  58.60   29  13  7  626   6
# 1  71.67    3   7  1  139  32
# 2  55.68    5   4  2  186   5
# 3  54.48    7  11  1  246  11
# 4  56.00   10   5  2  104   1

# %%
Cricket.tail()
# Out:
#                   Player       Span  Mat  Inns  NO   Runs    HS    Ave     BF  \
# 67       B Mitchell (SA)  1929-1949   42    80   9   3471  189*  48.88   158+
# 68  Hon.FS Jackson (ENG)  1893-1905   20    33   4   1415  144*  48.79    NaN
# 69   TT Samaraweera (SL)  2001-2013   81   132  20   5462   231  48.76  11641
# 70       RN Harvey (AUS)  1948-1963   79   137  10   6149   205  48.41  1799+
# 71      RT Ponting (AUS)  1995-2012  168   287  29  13378   257  51.85  22782
#
#        SR  100  50   0    4s  6s
# 67  29.11    8  21   3    41   1
# 68   0.00    5   6   3    51   0
# 69  46.92   14  30  11   633   7
# 70  43.74   21  24   7   427   1
# 71  58.72   41  62  17  1509  73

# %%
Cricket.describe()
# Out:
#               Mat        Inns         NO          Runs        Ave         SR  \
# count   72.000000   72.000000  72.000000     72.000000  72.000000  72.000000
# mean    78.500000  133.319444  13.763889   6269.777778  53.162083  46.957222
# std     51.273638   87.185059  10.942221   4051.240774   6.886532  15.904649
# min     11.000000   20.000000   1.000000    990.000000  48.000000   0.000000
# 25%     22.750000   40.750000   5.000000   2173.000000  49.100000  42.087500
# 50%     79.000000  132.000000  12.000000   6149.000000  51.445000  48.450000
# 75%    115.500000  195.750000  19.000000   8897.500000  55.092500  55.780000
# max    200.000000  329.000000  49.000000  15921.000000  99.940000  86.790000
#
#              100         50          0           4s         6s
# count  72.000000  72.000000  72.000000    72.000000  72.000000
# mean   18.875000  27.750000   7.708333   634.888889  26.138889
# std    12.567494  18.630393   5.532077   521.696381  26.766231
# ...

# %%
Cricket.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  72 non-null     object
#  1   Span    72 non-null     object
#  2   Mat     72 non-null     int64
#  3   Inns    72 non-null     int64
#  4   NO      72 non-null     int64
#  5   Runs    72 non-null     int64
#  6   HS      72 non-null     object
#  7   Ave     72 non-null     float64
#  8   BF      68 non-null     object
#  9   SR      72 non-null     float64
#  10  100     72 non-null     int64
#  11  50      72 non-null     int64
#  12  0       72 non-null     int64
#  13  4s      72 non-null     int64
#  14  6s      72 non-null     int64
# dtypes: float64(2), int64(9), object(4)
# memory usage: 8.6+ KB

# %%
Cricket = Cricket.drop_duplicates()

# %%
Cricket
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1   YBK Jaiswal (IND)  2023-2024   11    20   1  1217  214*  64.05   1698
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 58   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 59  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 60  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 61    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 62   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0   58.60   29  13   7   626   6
# ...

# %%
Cricket = Cricket.rename(columns={'Player': 'Player_Name', 'Span': 'Playing_Span', 'Mat': 'Matches_Played', 'Inns': 'Innings_Batted', 'NO': 'Not_Outs', 'Runs': 'Runs_Scored', 'HS': 'Highest_Inns_Scored', 'Ave': 'Battling_Average', 'BF': 'Balls_Faced', 'SR': 'Battling_Strike_Rate', '100': 'Hundreds_Scored', '50': 'Fifties_Scored', '0': 'Ducks_Scored', '4s': 'Boundary_Four', '6s': 'Boundary_Sixes'})

# %%
Cricket
# Out:
#           Player_Name Playing_Span  Matches_Played  Innings_Batted  Not_Outs  \
# 0    DG Bradman (AUS)    1928-1948              52              80        10
# 1   YBK Jaiswal (IND)    2023-2024              11              20         1
# 2      AC Voges (AUS)    2015-2016              20              31         7
# 3     RG Pollock (SA)    1963-1970              23              41         4
# 4     GA Headley (WI)    1930-1954              22              40         4
# ..                ...          ...             ...             ...       ...
# 58   KD Walters (AUS)    1965-1981              74             125        14
# 59  GC Smith (ICC/SA)    2002-2014             117             205        13
# 60  WH Ponsford (AUS)    1924-1934              29              48         4
# 61    SJ McCabe (AUS)    1930-1938              39              62         5
# 62   DR Jardine (ENG)    1928-1934              22              33         6
#
# ...

# %%
Cricket[['Player_Name','Country']] = Cricket['Player_Name'].str.split('(', n=2, expand=True)

# %%
Cricket
# Out:
#      Player_Name Playing_Span  Matches_Played  Innings_Batted  Not_Outs  \
# 0    DG Bradman     1928-1948              52              80        10
# 1   YBK Jaiswal     2023-2024              11              20         1
# 2      AC Voges     2015-2016              20              31         7
# 3    RG Pollock     1963-1970              23              41         4
# 4    GA Headley     1930-1954              22              40         4
# ..           ...          ...             ...             ...       ...
# 58   KD Walters     1965-1981              74             125        14
# 59     GC Smith     2002-2014             117             205        13
# 60  WH Ponsford     1924-1934              29              48         4
# 61    SJ McCabe     1930-1938              39              62         5
# 62   DR Jardine     1928-1934              22              33         6
#
#     Runs_Scored Highest_Inns_Scored  Battling_Average Balls_Faced  \
# ...

# %%
Cricket['Country'] = Cricket['Country'].str.strip(')')

# %%
Cricket
# Out:
#      Player_Name Playing_Span  Matches_Played  Innings_Batted  Not_Outs  \
# 0    DG Bradman     1928-1948              52              80        10
# 1   YBK Jaiswal     2023-2024              11              20         1
# 2      AC Voges     2015-2016              20              31         7
# 3    RG Pollock     1963-1970              23              41         4
# 4    GA Headley     1930-1954              22              40         4
# ..           ...          ...             ...             ...       ...
# 58   KD Walters     1965-1981              74             125        14
# 59     GC Smith     2002-2014             117             205        13
# 60  WH Ponsford     1924-1934              29              48         4
# 61    SJ McCabe     1930-1938              39              62         5
# 62   DR Jardine     1928-1934              22              33         6
#
#     Runs_Scored Highest_Inns_Scored  Battling_Average Balls_Faced  \
# ...

# %%
Cricket[['Starting_Year', 'Ending_Year']] = Cricket['Playing_Span'].str.split('-', n=2, expand=True)

# %%
Cricket
# Out:
#      Player_Name Playing_Span  Matches_Played  Innings_Batted  Not_Outs  \
# 0    DG Bradman     1928-1948              52              80        10
# 1   YBK Jaiswal     2023-2024              11              20         1
# 2      AC Voges     2015-2016              20              31         7
# 3    RG Pollock     1963-1970              23              41         4
# 4    GA Headley     1930-1954              22              40         4
# ..           ...          ...             ...             ...       ...
# 58   KD Walters     1965-1981              74             125        14
# 59     GC Smith     2002-2014             117             205        13
# 60  WH Ponsford     1924-1934              29              48         4
# 61    SJ McCabe     1930-1938              39              62         5
# 62   DR Jardine     1928-1934              22              33         6
#
#     Runs_Scored Highest_Inns_Scored  Battling_Average Balls_Faced  \
# ...

# %%
Cricket['Duration'] = Cricket['Ending_Year'].astype(int) - Cricket['Starting_Year'].astype(int)

# %%
Cricket
# Out:
#      Player_Name Playing_Span  Matches_Played  Innings_Batted  Not_Outs  \
# 0    DG Bradman     1928-1948              52              80        10
# 1   YBK Jaiswal     2023-2024              11              20         1
# 2      AC Voges     2015-2016              20              31         7
# 3    RG Pollock     1963-1970              23              41         4
# 4    GA Headley     1930-1954              22              40         4
# ..           ...          ...             ...             ...       ...
# 58   KD Walters     1965-1981              74             125        14
# 59     GC Smith     2002-2014             117             205        13
# 60  WH Ponsford     1924-1934              29              48         4
# 61    SJ McCabe     1930-1938              39              62         5
# 62   DR Jardine     1928-1934              22              33         6
#
#     Runs_Scored Highest_Inns_Scored  Battling_Average Balls_Faced  \
# ...

# %%
Cricket = Cricket.drop(columns= 'Playing_Span')

# %%
Cricket
# Out:
#      Player_Name  Matches_Played  Innings_Batted  Not_Outs  Runs_Scored  \
# 0    DG Bradman               52              80        10         6996
# 1   YBK Jaiswal               11              20         1         1217
# 2      AC Voges               20              31         7         1485
# 3    RG Pollock               23              41         4         2256
# 4    GA Headley               22              40         4         2190
# ..           ...             ...             ...       ...          ...
# 58   KD Walters               74             125        14         5357
# 59     GC Smith              117             205        13         9265
# 60  WH Ponsford               29              48         4         2122
# 61    SJ McCabe               39              62         5         2748
# 62   DR Jardine               22              33         6         1296
#
#    Highest_Inns_Scored  Battling_Average Balls_Faced  Battling_Strike_Rate  \
# ...

# %%
Cricket.isnull().sum()
# Out:
# Player_Name             0
# Matches_Played          0
# Innings_Batted          0
# Not_Outs                0
# Runs_Scored             0
# Highest_Inns_Scored     0
# Battling_Average        0
# Balls_Faced             3
# Battling_Strike_Rate    0
# Hundreds_Scored         0
# Fifties_Scored          0
# Ducks_Scored            0
# Boundary_Four           0
# Boundary_Sixes          0
# Country                 0
# Starting_Year           0
# Ending_Year             0
# Duration                0
# dtype: int64

# %%
Cricket['Balls_Faced'] = Cricket['Balls_Faced'].fillna(0)

# %%
Cricket
# Out:
#      Player_Name  Matches_Played  Innings_Batted  Not_Outs  Runs_Scored  \
# 0    DG Bradman               52              80        10         6996
# 1   YBK Jaiswal               11              20         1         1217
# 2      AC Voges               20              31         7         1485
# 3    RG Pollock               23              41         4         2256
# 4    GA Headley               22              40         4         2190
# ..           ...             ...             ...       ...          ...
# 58   KD Walters               74             125        14         5357
# 59     GC Smith              117             205        13         9265
# 60  WH Ponsford               29              48         4         2122
# 61    SJ McCabe               39              62         5         2748
# 62   DR Jardine               22              33         6         1296
#
#    Highest_Inns_Scored  Battling_Average Balls_Faced  Battling_Strike_Rate  \
# ...

# %%
Cricket['Balls_Faced']= Cricket['Balls_Faced'].str.split('+', expand=True)[0]

# %%
Cricket
# Out:
#      Player_Name  Matches_Played  Innings_Batted  Not_Outs  Runs_Scored  \
# 0    DG Bradman               52              80        10         6996
# 1   YBK Jaiswal               11              20         1         1217
# 2      AC Voges               20              31         7         1485
# 3    RG Pollock               23              41         4         2256
# 4    GA Headley               22              40         4         2190
# ..           ...             ...             ...       ...          ...
# 58   KD Walters               74             125        14         5357
# 59     GC Smith              117             205        13         9265
# 60  WH Ponsford               29              48         4         2122
# 61    SJ McCabe               39              62         5         2748
# 62   DR Jardine               22              33         6         1296
#
#    Highest_Inns_Scored  Battling_Average Balls_Faced  Battling_Strike_Rate  \
# ...

# %%
Cricket = Cricket.dropna(subset=['Balls_Faced'])

# %%
Cricket
# Out:
#           Player_Name  Matches_Played  Innings_Batted  Not_Outs  Runs_Scored  \
# 0         DG Bradman               52              80        10         6996
# 1        YBK Jaiswal               11              20         1         1217
# 2           AC Voges               20              31         7         1485
# 3         RG Pollock               23              41         4         2256
# 4         GA Headley               22              40         4         2190
# 5        H Sutcliffe               54              84         9         4555
# 6          E Paynter               20              31         5         1540
# 7      KF Barrington               82             131        15         6806
# 9         WR Hammond               85             140        16         7249
# 10         GS Sobers               93             160        21         8032
# 11     KC Sangakkara              134             233        17        12400
# ...

# %%
Cricket['Balls_Faced'] = Cricket['Balls_Faced'].astype(int)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_17612\2588431724.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Cricket['Balls_Faced'] = Cricket['Balls_Faced'].astype(int)

# %%
Cricket
# Out:
#           Player_Name  Matches_Played  Innings_Batted  Not_Outs  Runs_Scored  \
# 0         DG Bradman               52              80        10         6996
# 1        YBK Jaiswal               11              20         1         1217
# 2           AC Voges               20              31         7         1485
# 3         RG Pollock               23              41         4         2256
# 4         GA Headley               22              40         4         2190
# 5        H Sutcliffe               54              84         9         4555
# 6          E Paynter               20              31         5         1540
# 7      KF Barrington               82             131        15         6806
# 9         WR Hammond               85             140        16         7249
# 10         GS Sobers               93             160        21         8032
# 11     KC Sangakkara              134             233        17        12400
# ...

# %%
Cricket.isnull().sum()
# Out:
# Player_Name             0
# Matches_Played          0
# Innings_Batted          0
# Not_Outs                0
# Runs_Scored             0
# Highest_Inns_Scored     0
# Battling_Average        0
# Balls_Faced             0
# Battling_Strike_Rate    0
# Hundreds_Scored         0
# Fifties_Scored          0
# Ducks_Scored            0
# Boundary_Four           0
# Boundary_Sixes          0
# Country                 0
# Starting_Year           0
# Ending_Year             0
# Duration                0
# dtype: int64

# %%
Cricket.describe()
# Out:
#        Matches_Played  Innings_Batted   Not_Outs   Runs_Scored  \
# count       60.000000       60.000000  60.000000     60.000000
# mean        81.383333      138.066667  14.366667   6524.033333
# std         51.743858       88.017114  11.328630   4087.956304
# min         11.000000       20.000000   1.000000    990.000000
# 25%         27.500000       46.250000   5.750000   2239.500000
# 50%         80.000000      137.000000  12.500000   6888.500000
# 75%        118.500000      198.500000  19.000000   9026.500000
# max        200.000000      329.000000  49.000000  15921.000000
#
#        Battling_Average   Balls_Faced  Battling_Strike_Rate  Hundreds_Scored  \
# count         60.000000     60.000000             60.000000        60.000000
# mean          53.677833  10477.100000             50.078833        19.516667
# std            7.296890   9092.880798             11.529883        12.675202
# min           48.000000    108.000000             25.590000         1.000000
# ...

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(Cricket['Country'], Cricket['Duration'])
plt.xlabel('Country')
plt.ylabel('Duration')
# Out:
# Text(0, 0.5, 'Duration')
